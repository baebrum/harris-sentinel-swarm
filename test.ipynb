# %%
import os
import re

# Same settings as your vit.py
DATASET_ROOT = "/Users/jacobanderson/Documents/Spring 2025/CompE696/compe-696/Man-Woman"  # Adjust if needed
FILTER_PATTERN = r"(men|women)"

# Apply regex filtering
pattern = re.compile(FILTER_PATTERN)
all_folders = os.listdir(DATASET_ROOT)
filtered_classes = sorted([folder for folder in all_folders if pattern.search(folder)])

print("Your ViT class labels are:")
print(filtered_classes)
# Out:
# Your ViT class labels are:
# ['men', 'women']
